# %%
import pandas as pd

# Load your CSV file (make sure the path is correct)
df = pd.read_csv("Delinquency_prediction_dataset - Copy.csv")

# Preview first few rows
df.head()
# Out:
#   Customer_ID  Age    Income  Credit_Score  Credit_Utilization  \
# 0    CUST0001   56  165580.0         398.0            0.390502
# 1    CUST0002   69  100999.0         493.0            0.312444
# 2    CUST0003   46  188416.0         500.0            0.359930
# 3    CUST0004   32  101672.0         413.0            0.371400
# 4    CUST0005   60   38524.0         487.0            0.234716
#
#    Missed_Payments  Delinquent_Account  Loan_Balance  Debt_to_Income_Ratio  \
# 0                3                   0       16310.0              0.317396
# 1                6                   1       17401.0              0.196093
# 2                0                   0       13761.0              0.301655
# 3                3                   0       88778.0              0.264794
# 4                2                   0       13316.0              0.510583
#
#   Employment_Status  Account_Tenure Credit_Card_Type     Location Month_1  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Customer_ID           500 non-null    object
#  1   Age                   500 non-null    int64
#  2   Income                461 non-null    float64
#  3   Credit_Score          498 non-null    float64
#  4   Credit_Utilization    500 non-null    float64
#  5   Missed_Payments       500 non-null    int64
#  6   Delinquent_Account    500 non-null    int64
#  7   Loan_Balance          471 non-null    float64
#  8   Debt_to_Income_Ratio  500 non-null    float64
#  9   Employment_Status     500 non-null    object
#  10  Account_Tenure        500 non-null    int64
#  11  Credit_Card_Type      500 non-null    object
#  12  Location              500 non-null    object
#  13  Month_1               500 non-null    object
#  14  Month_2               500 non-null    object
# ...

# %%
df.describe()
# Out:
#               Age         Income  Credit_Score  Credit_Utilization  \
# count  500.000000     461.000000    498.000000          500.000000
# mean    46.266000  108379.893709    577.716867            0.491446
# std     16.187629   53662.723741    168.881211            0.197103
# min     18.000000   15404.000000    301.000000            0.050000
# 25%     33.000000   62295.000000    418.250000            0.356486
# 50%     46.500000  107658.000000    586.000000            0.485636
# 75%     59.250000  155734.000000    727.250000            0.634440
# max     74.000000  199943.000000    847.000000            1.025843
#
#        Missed_Payments  Delinquent_Account  Loan_Balance  \
# count       500.000000          500.000000    471.000000
# mean          2.968000            0.160000  48654.428875
# std           1.946935            0.366973  29395.537273
# min           0.000000            0.000000    612.000000
# 25%           1.000000            0.000000  23716.500000
# ...

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Income                  39
# Loan_Balance            29
# Credit_Score             2
# Customer_ID              0
# Credit_Card_Type         0
# Month_5                  0
# Month_4                  0
# Month_3                  0
# Month_2                  0
# Month_1                  0
# Location                 0
# Employment_Status        0
# Account_Tenure           0
# Age                      0
# Debt_to_Income_Ratio     0
# Delinquent_Account       0
# Missed_Payments          0
# Credit_Utilization       0
# Month_6                  0
# dtype: int64

# %%
df.select_dtypes(include='object').nunique().sort_values(ascending=False)
# Out:
# Customer_ID          500
# Employment_Status      6
# Credit_Card_Type       5
# Location               5
# Month_1                3
# Month_2                3
# Month_3                3
# Month_4                3
# Month_5                3
# Month_6                3
# dtype: int64

# %%
df['default_flag'].value_counts(normalize=True) * 100
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\Softwares\annaconda\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File C:\Softwares\annaconda\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\Softwares\annaconda\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'default_flag'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df.columns.tolist()
# Out:
# ['Customer_ID',
#  'Age',
#  'Income',
#  'Credit_Score',
#  'Credit_Utilization',
#  'Missed_Payments',
#  'Delinquent_Account',
#  'Loan_Balance',
#  'Debt_to_Income_Ratio',
#  'Employment_Status',
#  'Account_Tenure',
#  'Credit_Card_Type',
#  'Location',
#  'Month_1',
#  'Month_2',
#  'Month_3',
#  'Month_4',
#  'Month_5',
#  'Month_6']

# %%
df['Delinquent_Account'].value_counts(normalize=True) * 100
# Out:
# Delinquent_Account
# 0    84.0
# 1    16.0
# Name: proportion, dtype: float64

# %%
# Group by delinquency status and show average values
df.groupby('Delinquent_Account').mean(numeric_only=True).T
# Out:
# Delinquent_Account                0              1
# Age                       46.107143      47.100000
# Income                107306.943005  113902.013333
# Credit_Score             575.145933     591.150000
# Credit_Utilization         0.488505       0.506887
# Missed_Payments            2.990476       2.850000
# Loan_Balance           48708.756281   48358.232877
# Debt_to_Income_Ratio       0.297445       0.306301
# Account_Tenure             9.842857       9.200000

# %%
df.corr(numeric_only=True)['Delinquent_Account'].sort_values(ascending=False)
# Out:
# Delinquent_Account      1.000000
# Income                  0.045409
# Credit_Score            0.034833
# Debt_to_Income_Ratio    0.034386
# Credit_Utilization      0.034224
# Age                     0.022508
# Loan_Balance           -0.004320
# Missed_Payments        -0.026478
# Account_Tenure         -0.039829
# Name: Delinquent_Account, dtype: float64

# %%
df.isnull().sum().sort_values(ascending=False)
